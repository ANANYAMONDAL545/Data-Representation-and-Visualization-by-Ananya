# %%
import pandas as pd
import numpy as np
import seaborn as sns # seaborn library is used to plot any diagram 1-D or 2-D using python
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("/tips.csv")
data
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
data1=data.drop(['day'],axis='columns')

# %%
data1.isnull().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# time          0
# size          0
# dtype: int64

# %%
data2 = data.drop(['day'], axis='columns')
data2
# Out:
#      total_bill   tip     sex smoker    time  size
# 0         16.99  1.01  Female     No  Dinner     2
# 1         10.34  1.66    Male     No  Dinner     3
# 2         21.01  3.50    Male     No  Dinner     3
# 3         23.68  3.31    Male     No  Dinner     2
# 4         24.59  3.61  Female     No  Dinner     4
# ..          ...   ...     ...    ...     ...   ...
# 239       29.03  5.92    Male     No  Dinner     3
# 240       27.18  2.00  Female    Yes  Dinner     2
# 241       22.67  2.00    Male    Yes  Dinner     2
# 242       17.82  1.75    Male     No  Dinner     2
# 243       18.78  3.00  Female     No  Dinner     2
#
# [244 rows x 6 columns]

# %%
# we want to run any query
# we want to display the details of those customer who paid more than $6 as tip
data[data.tip>9.00]
# Out:
#      total_bill   tip   sex smoker  day    time  size
# 170       50.81  10.0  Male    Yes  Sat  Dinner     3

# %%
# we want to display the details of coutomers who paid above 30$ as total bill
data[data.total_bill>30]
# Out:
#      total_bill    tip     sex smoker   day    time  size
# 11        35.26   5.00  Female     No   Sun  Dinner     4
# 23        39.42   7.58    Male     No   Sat  Dinner     4
# 39        31.27   5.00    Male     No   Sat  Dinner     3
# 44        30.40   5.60    Male     No   Sun  Dinner     4
# 47        32.40   6.00    Male     No   Sun  Dinner     4
# 52        34.81   5.20  Female     No   Sun  Dinner     4
# 56        38.01   3.00    Male    Yes   Sat  Dinner     4
# 59        48.27   6.73    Male     No   Sat  Dinner     4
# 83        32.68   5.00    Male    Yes  Thur   Lunch     2
# 85        34.83   5.17  Female     No  Thur   Lunch     4
# 95        40.17   4.73    Male    Yes   Fri  Dinner     4
# 102       44.30   2.50  Female    Yes   Sat  Dinner     3
# 112       38.07   4.00    Male     No   Sun  Dinner     3
# 141       34.30   6.70    Male     No  Thur   Lunch     6
# 142       41.19   5.00    Male     No  Thur   Lunch     5
# ...

# %%
data['tip'].hist(bins=10)
# Out:
# <Axes: >

# %%
data1=data.drop(['day'],axis=1)
data1
# Out:
#      total_bill   tip     sex smoker    time  size
# 0         16.99  1.01  Female     No  Dinner     2
# 1         10.34  1.66    Male     No  Dinner     3
# 2         21.01  3.50    Male     No  Dinner     3
# 3         23.68  3.31    Male     No  Dinner     2
# 4         24.59  3.61  Female     No  Dinner     4
# ..          ...   ...     ...    ...     ...   ...
# 239       29.03  5.92    Male     No  Dinner     3
# 240       27.18  2.00  Female    Yes  Dinner     2
# 241       22.67  2.00    Male    Yes  Dinner     2
# 242       17.82  1.75    Male     No  Dinner     2
# 243       18.78  3.00  Female     No  Dinner     2
#
# [244 rows x 6 columns]

# %%
data['tip'].hist(bins=40)
# Out:
# <Axes: >

# %%
data[data.total_bill>50.78] # query to display customer details for those who have given more than 50$
# Out:
#      total_bill   tip   sex smoker  day    time  size
# 170       50.81  10.0  Male    Yes  Sat  Dinner     3

# %%
data[data.tip>5.45]
# Out:
#      total_bill    tip     sex smoker   day    time  size
# 23        39.42   7.58    Male     No   Sat  Dinner     4
# 44        30.40   5.60    Male     No   Sun  Dinner     4
# 47        32.40   6.00    Male     No   Sun  Dinner     4
# 59        48.27   6.73    Male     No   Sat  Dinner     4
# 88        24.71   5.85    Male     No  Thur   Lunch     2
# 141       34.30   6.70    Male     No  Thur   Lunch     6
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3
# 181       23.33   5.65    Male    Yes   Sun  Dinner     2
# 183       23.17   6.50    Male    Yes   Sun  Dinner     4
# 212       48.33   9.00    Male     No   Sat  Dinner     4
# 214       28.17   6.50  Female    Yes   Sat  Dinner     3
# 239       29.03   5.92    Male     No   Sat  Dinner     3

# %%
data1=data.drop(['day'],axis='columns')

# %%
sns.violinplot(data=data,x="tip",y="total_bill",color="red")
plt.title("Violin Plot")
plt.xlabel("Tip")
plt.ylabel("Total Bill")
plt.show()

# %%
saikat=[3,5,7,8,9,12]
plt.plot(saikat,'*')
plt.show()

# %%
saikat=[3,5,7,8,9,12]
plt.plot(saikat)
plt.show()

# %%
saikat=[13,5,7,8,9,2]
plt.plot(saikat)
plt.show()

# %%
sneha=[23,25,27,83,9,2]
plt.plot(sneha)
plt.show()

# %%
df=pd.read_csv("/tips.csv")
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.isnull().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
df['size'].fillna(df['size'].mean(),inplace=True)
df.isnull().sum()
# Out:
# /tmp/ipython-input-33-3295137557.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['size'].fillna(df['size'].mean(),inplace=True)
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
sns.displot(x='size',data=df)

# %%
# Correlation: two categorical or numerical values are realted or not
corr=df[['Age','Fare','Pclass']].corr()
print(corr)
sns.heatmap(corr)
# Out:
#              Age      Fare    Pclass
# Age     1.000000  0.091566 -0.331339
# Fare    0.091566  1.000000 -0.549500
# Pclass -0.331339 -0.549500  1.000000
# <Axes: >

# %%
# how to plot distribution ploting
sns.displot(x='tip',data=df)

# %%
# correlation:  how more than two categorical or numerical attributes are related to each other
corr=df[['Age','Fare','Pclass']].corr()
sns.heatmap(corr)
# Out:
# <Axes: >

# %%
df['size'].fillna(df['size'].median(),inplace=True)
# Out:
# /tmp/ipython-input-38-1041482713.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['size'].fillna(df['size'].median(),inplace=True)

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.isnull() # returns boolean values True or false and it shows where value is null.
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
sns.histplot(data=df,x='tip')
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.notnull().sum()
# Out:
# PassengerId    891
# Survived       891
# Pclass         891
# Name           891
# Sex            891
# Age            714
# SibSp          891
# Parch          891
# Ticket         891
# Fare           891
# Cabin          204
# Embarked       889
# dtype: int64

# %%
age=df["Age"]
plt.plot(age)
plt.show()

# %%
age=df["Age"]
plt.plot(age,color='green',label='age')
plt.legend()
plt.show()

# %%
sns.boxplot(df['Age']) #using this boxplot we can represent outliners
# Out:
# <Axes: ylabel='Age'>

# %%
df.isnull().mean()
# Out:
# PassengerId    0.000000
# Survived       0.000000
# Pclass         0.000000
# Name           0.000000
# Sex            0.000000
# Age            0.198653
# SibSp          0.000000
# Parch          0.000000
# Ticket         0.000000
# Fare           0.000000
# Cabin          0.771044
# Embarked       0.002245
# dtype: float64

# %%
df['Cabin']
# Out:
# 0       NaN
# 1       C85
# 2       NaN
# 3      C123
# 4       NaN
#        ...
# 886     NaN
# 887     B42
# 888     NaN
# 889    C148
# 890     NaN
# Name: Cabin, Length: 891, dtype: object

# %%
df['Cabin_bca']=np.where(df['Cabin'].isnull(),1,0) # replace by 1 where values are NaN or null and replace by 0 where values are present in Cabin column
df['Cabin_bca'].head()
# Out:
# 0    1
# 1    0
# 2    1
# 3    0
# 4    1
# Name: Cabin_bca, dtype: int64

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# Cabin_bca        0
# dtype: int64

# %%
age=df['Age']
plt.plot(age)
plt.show()

# %%
age=df['smoker']
plt.plot(age,color='red',label='AGE')
plt.legend()
plt.show()

# %%
sns.boxplot(df['Age']) # There is lots of null valus and outliers in Age columns
# Out:
# <Axes: ylabel='Age'>

# %%
age=[20,21,22,67]

# %%
df.notnull().sum()
# Out:
# total_bill      244
# tip             244
# sex             244
# smoker          244
# day             244
# time            244
# size            244
# tip_fraction    244
# dtype: int64

# %%
df['tip'].fillna(df['tip'].mean())
# Out:
# 0      1.01
# 1      1.66
# 2      3.50
# 3      3.31
# 4      3.61
#        ...
# 239    5.92
# 240    2.00
# 241    2.00
# 242    1.75
# 243    3.00
# Name: tip, Length: 244, dtype: float64

# %%
df=pd.read_csv("/tips.csv")
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.scatterplot(x='total_bill',y='tip',data=df) # scatterplot is used to find the ratio between two attributs
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
# how to add one new column in a dataframe
df['tip_bca']=df['total_bill']/df['tip']
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size    tip_bca
# 0       16.99  1.01  Female     No  Sun  Dinner     2  16.821782
# 1       10.34  1.66    Male     No  Sun  Dinner     3   6.228916
# 2       21.01  3.50    Male     No  Sun  Dinner     3   6.002857
# 3       23.68  3.31    Male     No  Sun  Dinner     2   7.154079
# 4       24.59  3.61  Female     No  Sun  Dinner     4   6.811634

# %%
sns.scatterplot(x='total_bill',y='tip',data=df,hue='smoker')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.histplot(x="tip",data=df,kde=True)
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
sns.scatterplot(x='total_bill',y='tip',data=df) #scatterplot is used to find the ratio between two variables
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
# How to add new columns in a dataframe where column name is userfined
df['tip_fraction']=df['total_bill']/df['tip']
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  tip_fraction
# 0       16.99  1.01  Female     No  Sun  Dinner     2     16.821782
# 1       10.34  1.66    Male     No  Sun  Dinner     3      6.228916
# 2       21.01  3.50    Male     No  Sun  Dinner     3      6.002857
# 3       23.68  3.31    Male     No  Sun  Dinner     2      7.154079
# 4       24.59  3.61  Female     No  Sun  Dinner     4      6.811634

# %%
sns.scatterplot(x='total_bill',y='tip',data=df,hue='time')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.histplot(data=df,x='tip')
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
df['day']
# Out:
# 0       Sun
# 1       Sun
# 2       Sun
# 3       Sun
# 4       Sun
#        ...
# 239     Sat
# 240     Sat
# 241     Sat
# 242     Sat
# 243    Thur
# Name: day, Length: 244, dtype: object

# %%
df.groupby('day').count()
# Out:
#       total_bill  tip  sex  smoker  time  size
# day
# Fri           19   19   19      19    19    19
# Sat           87   87   87      87    87    87
# Sun           76   76   76      76    76    76
# Thur          62   62   62      62    62    62

# %%
df.nunique()
# Out:
# total_bill    229
# tip           123
# sex             2
# smoker          2
# day             4
# time            2
# size            6
# dtype: int64

# %%
df.isnull().sum() # I am giving you 5-7 mins to run only this line on Titanic dataset so that you can dufferenciate
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
sns.barplot(x='day', y='total_bill',data=df)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(x='sex', y='total_bill',data=df)
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
sns.barplot(x='smoker', y='total_bill',data=df)
# Out:
# <Axes: xlabel='smoker', ylabel='total_bill'>

# %%
sns.jointplot(x='total_bill',y='tip',data=df)

# %%
sns.jointplot(x='day',y='tip',data=df)# y-mx+c where we need to find y based on x

# %%
sns.barplot(x='smoker', y='tip',data=df)
# Out:
# <Axes: xlabel='smoker', ylabel='tip'>

# %%
sns.pairplot(df,hue='smoker')

# %%
sns.pairplot(df,hue='sex',palette='Reds')

# %%
df['tip'].max()
# Out:
# 10.0

# %%
df['total_bill']
# Out:
# 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
#        ...
# 239    29.03
# 240    27.18
# 241    22.67
# 242    17.82
# 243    18.78
# Name: total_bill, Length: 244, dtype: float64

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
df.shape # it returns no of rows and columns
# Out:
# (244, 7)

# %%
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
df.index # index of any particular dataset
# Out:
# RangeIndex(start=0, stop=244, step=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB

# %%
df.dtypes
# Out:
# total_bill    float64
# tip           float64
# sex            object
# smoker         object
# day            object
# time           object
# size            int64
# dtype: object

# %%
df.dtypes.value_counts() # it returns how many variables in each data type
# Out:
# object     4
# float64    2
# int64      1
# Name: count, dtype: int64

# %%
df['tip'].max()
# Out:
# 10.0

# %%
df['tip'].mean()
# Out:
# 2.99827868852459

# %%
df['tip'].describe()
# Out:
# count    244.000000
# mean       2.998279
# std        1.383638
# min        1.000000
# 25%        2.000000
# 50%        2.900000
# 75%        3.562500
# max       10.000000
# Name: tip, dtype: float64

# %%
df.sort_values(by='tip')
# Out:
#      total_bill    tip     sex smoker   day    time  size
# 67         3.07   1.00  Female    Yes   Sat  Dinner     1
# 236       12.60   1.00    Male    Yes   Sat  Dinner     2
# 92         5.75   1.00  Female    Yes   Fri  Dinner     2
# 111        7.25   1.00  Female     No   Sat  Dinner     1
# 0         16.99   1.01  Female     No   Sun  Dinner     2
# ..          ...    ...     ...    ...   ...     ...   ...
# 141       34.30   6.70    Male     No  Thur   Lunch     6
# 59        48.27   6.73    Male     No   Sat  Dinner     4
# 23        39.42   7.58    Male     No   Sat  Dinner     4
# 212       48.33   9.00    Male     No   Sat  Dinner     4
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3
#
# [244 rows x 7 columns]

# %%
df.sort_values(by='tip').tail()
# Out:
#      total_bill    tip   sex smoker   day    time  size
# 141       34.30   6.70  Male     No  Thur   Lunch     6
# 59        48.27   6.73  Male     No   Sat  Dinner     4
# 23        39.42   7.58  Male     No   Sat  Dinner     4
# 212       48.33   9.00  Male     No   Sat  Dinner     4
# 170       50.81  10.00  Male    Yes   Sat  Dinner     3

# %%
df.sort_values(by='tip')
# Out:
#      total_bill    tip     sex smoker   day    time  size
# 67         3.07   1.00  Female    Yes   Sat  Dinner     1
# 236       12.60   1.00    Male    Yes   Sat  Dinner     2
# 92         5.75   1.00  Female    Yes   Fri  Dinner     2
# 111        7.25   1.00  Female     No   Sat  Dinner     1
# 0         16.99   1.01  Female     No   Sun  Dinner     2
# ..          ...    ...     ...    ...   ...     ...   ...
# 141       34.30   6.70    Male     No  Thur   Lunch     6
# 59        48.27   6.73    Male     No   Sat  Dinner     4
# 23        39.42   7.58    Male     No   Sat  Dinner     4
# 212       48.33   9.00    Male     No   Sat  Dinner     4
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3
#
# [244 rows x 7 columns]

# %%
df.sort_values(by='tip',ascending=False).head()
# Out:
#      total_bill    tip   sex smoker   day    time  size
# 170       50.81  10.00  Male    Yes   Sat  Dinner     3
# 212       48.33   9.00  Male     No   Sat  Dinner     4
# 23        39.42   7.58  Male     No   Sat  Dinner     4
# 59        48.27   6.73  Male     No   Sat  Dinner     4
# 141       34.30   6.70  Male     No  Thur   Lunch     6

# %%
df['sex'].describe()
# Out:
# count      244
# unique       2
# top       Male
# freq       157
# Name: sex, dtype: object

# %%
df['sex'].value_counts()
# Out:
# sex
# Male      157
# Female     87
# Name: count, dtype: int64

# %%
pd.DataFrame(df['sex'].value_counts())
# Out:
#         count
# sex
# Male      157
# Female     87

# %%
df['sex'][df.tip>=5.99].value_counts()
# Out:
# sex
# Male      7
# Female    1
# Name: count, dtype: int64

# %%
df.sex='male'
df
# Out:
#      total_bill   tip   sex smoker   day    time  size
# 0         16.99  1.01  male     No   Sun  Dinner     2
# 1         10.34  1.66  male     No   Sun  Dinner     3
# 2         21.01  3.50  male     No   Sun  Dinner     3
# 3         23.68  3.31  male     No   Sun  Dinner     2
# 4         24.59  3.61  male     No   Sun  Dinner     4
# ..          ...   ...   ...    ...   ...     ...   ...
# 239       29.03  5.92  male     No   Sat  Dinner     3
# 240       27.18  2.00  male    Yes   Sat  Dinner     2
# 241       22.67  2.00  male    Yes   Sat  Dinner     2
# 242       17.82  1.75  male     No   Sat  Dinner     2
# 243       18.78  3.00  male     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
print(df['sex'].value_counts().get('Male'))
# Out:
# None

# %%
male_tip=df[df["sex"]=="Male"]
print(male_tip)
# Out:
# Empty DataFrame
# Columns: [total_bill, tip, sex, smoker, day, time, size]
# Index: []

# %%
sns.countplot(x='smoker',data=df,hue = 'sex')
# Out:
# <Axes: xlabel='smoker', ylabel='count'>

# %%
sns.scatterplot(x='total_bill',y='tip',data=df)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
df
# Out:
#      total_bill   tip   sex smoker   day    time  size  tip_fraction
# 0         16.99  1.01  male     No   Sun  Dinner     2      0.059447
# 1         10.34  1.66  male     No   Sun  Dinner     3      0.160542
# 2         21.01  3.50  male     No   Sun  Dinner     3      0.166587
# 3         23.68  3.31  male     No   Sun  Dinner     2      0.139780
# 4         24.59  3.61  male     No   Sun  Dinner     4      0.146808
# ..          ...   ...   ...    ...   ...     ...   ...           ...
# 239       29.03  5.92  male     No   Sat  Dinner     3      0.203927
# 240       27.18  2.00  male    Yes   Sat  Dinner     2      0.073584
# 241       22.67  2.00  male    Yes   Sat  Dinner     2      0.088222
# 242       17.82  1.75  male     No   Sat  Dinner     2      0.098204
# 243       18.78  3.00  male     No  Thur  Dinner     2      0.159744
#
# [244 rows x 8 columns]

# %%
df['tip_fraction']=df['tip']/df['total_bill']

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
sns.histplot(data=df,x='tip')
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
data1=data.drop(['day'],axis='columns')
