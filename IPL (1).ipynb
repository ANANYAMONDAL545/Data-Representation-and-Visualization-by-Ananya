# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("/content/IPL.dataset.csv")
data
# Out:
#       id  season        city        date                  team1  \
# 0      1    2008   Bangalore  18-04-2008  Kolkata Knight Riders
# 1      2    2008  Chandigarh  19-04-2008    Chennai Super Kings
# 2      3    2008       Delhi  19-04-2008       Rajasthan Royals
# 3      4    2008      Mumbai  20-04-2008         Mumbai Indians
# 4      5    2008     Kolkata  20-04-2008        Deccan Chargers
# ..   ...     ...         ...         ...                    ...
# 572  573    2016      Raipur  22-05-2016       Delhi Daredevils
# 573  574    2016   Bangalore  24-05-2016          Gujarat Lions
# 574  575    2016       Delhi  25-05-2016    Sunrisers Hyderabad
# 575  576    2016       Delhi  27-05-2016          Gujarat Lions
# 576  577    2016   Bangalore  29-05-2016    Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 0    Royal Challengers Bangalore  Royal Challengers Bangalore         field
# ...

# %%
data.head(10)
# Out:
#    id  season        city        date                  team1  \
# 0   1    2008   Bangalore  18-04-2008  Kolkata Knight Riders
# 1   2    2008  Chandigarh  19-04-2008    Chennai Super Kings
# 2   3    2008       Delhi  19-04-2008       Rajasthan Royals
# 3   4    2008      Mumbai  20-04-2008         Mumbai Indians
# 4   5    2008     Kolkata  20-04-2008        Deccan Chargers
# 5   6    2008      Jaipur  21-04-2008        Kings XI Punjab
# 6   7    2008   Hyderabad  22-04-2008        Deccan Chargers
# 7   8    2008     Chennai  23-04-2008    Chennai Super Kings
# 8   9    2008   Hyderabad  24-04-2008        Deccan Chargers
# 9  10    2008  Chandigarh  25-04-2008        Kings XI Punjab
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1              Kings XI Punjab          Chennai Super Kings           bat
# ...

# %%
data[0:8]
# Out:
#    id  season        city        date                  team1  \
# 0   1    2008   Bangalore  18-04-2008  Kolkata Knight Riders
# 1   2    2008  Chandigarh  19-04-2008    Chennai Super Kings
# 2   3    2008       Delhi  19-04-2008       Rajasthan Royals
# 3   4    2008      Mumbai  20-04-2008         Mumbai Indians
# 4   5    2008     Kolkata  20-04-2008        Deccan Chargers
# 5   6    2008      Jaipur  21-04-2008        Kings XI Punjab
# 6   7    2008   Hyderabad  22-04-2008        Deccan Chargers
# 7   8    2008     Chennai  23-04-2008    Chennai Super Kings
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1              Kings XI Punjab          Chennai Super Kings           bat
# 2             Delhi Daredevils             Rajasthan Royals           bat
# 3  Royal Challengers Bangalore               Mumbai Indians           bat
# ...

# %%
data.tail(5)
# Out:
#       id  season       city        date                team1  \
# 572  573    2016     Raipur  22-05-2016     Delhi Daredevils
# 573  574    2016  Bangalore  24-05-2016        Gujarat Lions
# 574  575    2016      Delhi  25-05-2016  Sunrisers Hyderabad
# 575  576    2016      Delhi  27-05-2016        Gujarat Lions
# 576  577    2016  Bangalore  29-05-2016  Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 572  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 573  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 574        Kolkata Knight Riders        Kolkata Knight Riders         field
# 575          Sunrisers Hyderabad          Sunrisers Hyderabad         field
# 576  Royal Challengers Bangalore          Sunrisers Hyderabad           bat
#
#      result  dl_applied                       winner  win_by_runs  \
# 572  normal           0  Royal Challengers Bangalore            0
# ...

# %%
data[10:]
# Out:
#       id  season        city        date                        team1  \
# 10    11    2008   Bangalore  26-04-2008  Royal Challengers Bangalore
# 11    12    2008     Chennai  26-04-2008        Kolkata Knight Riders
# 12    13    2008      Mumbai  27-04-2008               Mumbai Indians
# 13    14    2008  Chandigarh  27-04-2008             Delhi Daredevils
# 14    15    2008   Bangalore  28-04-2008          Chennai Super Kings
# ..   ...     ...         ...         ...                          ...
# 572  573    2016      Raipur  22-05-2016             Delhi Daredevils
# 573  574    2016   Bangalore  24-05-2016                Gujarat Lions
# 574  575    2016       Delhi  25-05-2016          Sunrisers Hyderabad
# 575  576    2016       Delhi  27-05-2016                Gujarat Lions
# 576  577    2016   Bangalore  29-05-2016          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
data[0::5]
# Out:
#       id  season           city        date                        team1  \
# 0      1    2008      Bangalore  18-04-2008        Kolkata Knight Riders
# 5      6    2008         Jaipur  21-04-2008              Kings XI Punjab
# 10    11    2008      Bangalore  26-04-2008  Royal Challengers Bangalore
# 15    16    2008        Kolkata  29-04-2008        Kolkata Knight Riders
# 20    21    2008      Hyderabad  25-05-2008              Deccan Chargers
# ..   ...     ...            ...         ...                          ...
# 555  556    2016     Chandigarh  09-05-2016  Royal Challengers Bangalore
# 560  561    2016      Bangalore  14-05-2016  Royal Challengers Bangalore
# 565  566    2016  Visakhapatnam  17-05-2016             Delhi Daredevils
# 570  571    2016         Kanpur  21-05-2016               Mumbai Indians
# 575  576    2016          Delhi  27-05-2016                Gujarat Lions
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 577 entries, 0 to 576
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               577 non-null    int64
#  1   season           577 non-null    int64
#  2   city             570 non-null    object
#  3   date             577 non-null    object
#  4   team1            577 non-null    object
#  5   team2            577 non-null    object
#  6   toss_winner      577 non-null    object
#  7   toss_decision    577 non-null    object
#  8   result           577 non-null    object
#  9   dl_applied       577 non-null    int64
#  10  winner           574 non-null    object
#  11  win_by_runs      577 non-null    int64
#  12  win_by_wickets   577 non-null    int64
#  13  player_of_match  574 non-null    object
#  14  venue            577 non-null    object
#  15  umpire1          577 non-null    object
#  16  umpire2          577 non-null    object
# ...

# %%
data.describe()
# Out:
#                id       season  dl_applied  win_by_runs  win_by_wickets  \
# count  577.000000   577.000000  577.000000   577.000000      577.000000
# mean   289.000000  2012.029463    0.025997    13.715771        3.363951
# std    166.709828     2.486247    0.159263    23.619282        3.416049
# min      1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%    145.000000  2010.000000    0.000000     0.000000        0.000000
# 50%    289.000000  2012.000000    0.000000     0.000000        3.000000
# 75%    433.000000  2014.000000    0.000000    20.000000        6.000000
# max    577.000000  2016.000000    1.000000   144.000000       10.000000
#
#        umpire3
# count      0.0
# mean       NaN
# std        NaN
# min        NaN
# 25%        NaN
# 50%        NaN
# 75%        NaN
# max        NaN

# %%
data.columns.value_counts()
# Out:
# id                 1
# season             1
# umpire2            1
# umpire1            1
# venue              1
# player_of_match    1
# win_by_wickets     1
# win_by_runs        1
# winner             1
# dl_applied         1
# result             1
# toss_decision      1
# toss_winner        1
# team2              1
# team1              1
# date               1
# city               1
# umpire3            1
# Name: count, dtype: int64

# %%
data.shape
# Out:
# (577, 18)

# %%
data.columns.values
# Out:
# array(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'], dtype=object)

# %%
data['win_by_runs'].mode()
# Out:
# 0    0
# Name: win_by_runs, dtype: int64

# %%
data['win_by_runs'].mean()
# Out:
# 13.7157712305026

# %%
data['win_by_runs'].median()
# Out:
# 0.0

# %%
data.dtypes.value_counts()
# Out:
# object     12
# int64       5
# float64     1
# Name: count, dtype: int64

# %%
data.sort_values(by='win_by_wickets')
# Out:
#       id  season        city        date                        team1  \
# 0      1    2008   Bangalore  18-04-2008        Kolkata Knight Riders
# 324  325    2013   Hyderabad  05-04-2013          Sunrisers Hyderabad
# 323  324    2013   Bangalore  04-04-2013  Royal Challengers Bangalore
# 320  321    2012     Chennai  25-05-2012          Chennai Super Kings
# 319  320    2012   Bangalore  23-05-2012          Chennai Super Kings
# ..   ...     ...         ...         ...                          ...
# 60    61    2009   Cape Town  19-04-2009              Kings XI Punjab
# 331  332    2013  Chandigarh  10-04-2013              Kings XI Punjab
# 12    13    2008      Mumbai  27-04-2008               Mumbai Indians
# 317  318    2012      Jaipur  20-05-2012             Rajasthan Royals
# 483  484    2015       Delhi  26-04-2015             Delhi Daredevils
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
data.sort_values(by='win_by_wickets').tail(10)
# Out:
#       id  season          city        date                team1  \
# 36    37    2008        Mumbai  14-05-2008  Chennai Super Kings
# 83    84    2009  Johannesburg  03-05-2009       Mumbai Indians
# 124  125    2010     Bangalore  18-03-2010     Rajasthan Royals
# 531  532    2016        Rajkot  21-04-2016        Gujarat Lions
# 239  240    2011        Mumbai  20-05-2011       Mumbai Indians
# 60    61    2009     Cape Town  19-04-2009      Kings XI Punjab
# 331  332    2013    Chandigarh  10-04-2013      Kings XI Punjab
# 12    13    2008        Mumbai  27-04-2008       Mumbai Indians
# 317  318    2012        Jaipur  20-05-2012     Rajasthan Royals
# 483  484    2015         Delhi  26-04-2015     Delhi Daredevils
#
#                            team2                  toss_winner toss_decision  \
# 36                Mumbai Indians               Mumbai Indians         field
# 83   Royal Challengers Bangalore               Mumbai Indians           bat
# ...

# %%
data['win_by_runs'].value_counts()
# Out:
# win_by_runs
# 0      316
# 23       9
# 10       8
# 24       8
# 9        8
#       ...
# 53       1
# 75       1
# 105      1
# 66       1
# 80       1
# Name: count, Length: 83, dtype: int64

# %%
data['win_by_runs'].unique()
# Out:
# array([140,  33,   0,   6,  66,  13,  10,  45,   9,  29,   5,  18,  23,
#         41,  12,  65,  25,   3,   1,  14, 105,  19,  75,  92,  11,  24,
#         27,  38,   8,  78,  16,  53,   2,   4,  31,  55,  98,  34,  36,
#         39,  17,  40,  67,  63,  37,  57,  35,  22,  21,  48,  26,  20,
#         85,  32,  76, 111,  82,  43,  58,  28,  74,  42,  59,  46,   7,
#         47,  86,  44,  87, 130,  15,  60,  77,  30,  50,  93,  72,  62,
#         97, 138,  71, 144,  80])

# %%
data['win_by_runs'].describe()
# Out:
# count    577.000000
# mean      13.715771
# std       23.619282
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%       20.000000
# max      144.000000
# Name: win_by_runs, dtype: float64

# %%
data['win_by_wickets'].describe()
# Out:
# count    577.000000
# mean       3.363951
# std        3.416049
# min        0.000000
# 25%        0.000000
# 50%        3.000000
# 75%        6.000000
# max       10.000000
# Name: win_by_wickets, dtype: float64

# %%
data['win_by_runs'].max()
# Out:
# 144

# %%
data['win_by_runs'].min()
# Out:
# 0

# %%
data.groupby('win_by_runs').count()
# Out:
#               id  season  city  date  team1  team2  toss_winner  \
# win_by_runs
# 0            316     316   312   316    316    316          316
# 1              7       7     7     7      7      7            7
# 2              7       7     7     7      7      7            7
# 3              3       3     3     3      3      3            3
# 4              7       7     6     7      7      7            7
# ...          ...     ...   ...   ...    ...    ...          ...
# 111            1       1     1     1      1      1            1
# 130            1       1     1     1      1      1            1
# 138            1       1     1     1      1      1            1
# 140            1       1     1     1      1      1            1
# 144            1       1     1     1      1      1            1
#
#              toss_decision  result  dl_applied  winner  win_by_wickets  \
# win_by_runs
# 0                      316     316         316     313             316
# ...

# %%
data['win_by_runs'].count()
# Out:
# 577

# %%
data.isnull().sum()
# Out:
# id                   0
# season               0
# city                 7
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               3
# win_by_runs          0
# win_by_wickets       0
# player_of_match      3
# venue                0
# umpire1              0
# umpire2              0
# umpire3            577
# dtype: int64

# %%
sns.pairplot(data)

# %%
sns.barplot(x='win_by_wickets',y='win_by_runs',data=data,hue='winner')
# Out:
# <Axes: xlabel='win_by_wickets', ylabel='win_by_runs'>

# %%
sns.barplot(x='win_by_wickets',y='win_by_runs',data=data)
# Out:
# <Axes: xlabel='win_by_wickets', ylabel='win_by_runs'>

# %%
sns.jointplot(x='win_by_runs',y='winner',data=data)

# %%
sns.pairplot(data,hue='win_by_runs')

# %%
sns.countplot(x='win_by_wickets',data=data,hue='win_by_runs')
# Out:
# <Axes: xlabel='win_by_wickets', ylabel='count'>

# %%
corr=data[['win_by_runs','win_by_wickets']].corr()
corr
# Out:
#                 win_by_runs  win_by_wickets
# win_by_runs        1.000000       -0.572839
# win_by_wickets    -0.572839        1.000000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['win_by_runs'].plot(kind='hist', bins=20, title='win_by_runs')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['win_by_wickets'].plot(kind='hist', bins=20, title='win_by_wickets')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_2.groupby('index').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# ...

# %%
corr=data[['win_by_wickets','win_by_runs']].corr()
sns.heatmap(corr)
# Out:
# <Axes: >

# %%
sns.distplot(data['win_by_wickets'])
# Out:
# <ipython-input-47-61f39a093953>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['win_by_wickets'])
# <Axes: xlabel='win_by_wickets', ylabel='Density'>

# %%
sns.scatterplot(x='win_by_wickets',y='win_by_runs',data=data,hue='winner')
# Out:
# <Axes: xlabel='win_by_wickets', ylabel='win_by_runs'>

# %%
plt.plot(data["id"],color="red",label='id')
plt.legend()
plt.show()

# %%
sns.histplot(data=data,x="win_by_wickets")
plt.show()

# %%
sns.boxplot(data=data,x="win_by_runs")
# Out:
# <Axes: xlabel='win_by_runs'>

# %%
sns.jointplot(x="win_by_wickets",y="win_by_runs",data=df,kind="resid")

# %%
sns.displot(x='win_by_runs',data=data)

# %%
print("thank you!!")
# Out:
# thank you!!
